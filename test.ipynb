# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/alokk/Downloads/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.rename(columns={"Sex":"gender"},inplace=True)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
my=['Survived', 'Age', 'SibSp',
       'Parch', 'Fare', ]
for i in  my:
    plt.figure(figsize=(6,4))
    sns.histplot(df[i],kde=True,bins=20)

# %%
sns.countplot(x="gender",data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.drop(['PassengerId','Ticket','Ticket','Name','Cabin','Parch','SibSp','Pclass','Fare'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    Survived  gender   Age Embarked
# 0         0    male  22.0        S
# 1         1  female  38.0        C

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["gender"]=le.fit_transform(df["gender"])

# %%
df.head()
# Out:
#    Survived  gender   Age Embarked
# 0         0       1  22.0        S
# 1         1       0  38.0        C
# 2         1       0  26.0        S
# 3         1       0  35.0        S
# 4         0       1  35.0        S

# %%
df=pd.get_dummies(df,columns=["Embarked"],dtype=int)

# %%
df.head()
# Out:
#    Survived  gender   Age  Embarked_C  Embarked_Q  Embarked_S
# 0         0       1  22.0           0           0           1
# 1         1       0  38.0           1           0           0
# 2         1       0  26.0           0           0           1
# 3         1       0  35.0           0           0           1
# 4         0       1  35.0           0           0           1

# %%
from sklearn.preprocessing import StandardScaler
d=["Age"]
scaler=StandardScaler()
df[d]=scaler.fit_transform(df[d])
df
# Out:
#      Survived  gender       Age  Embarked_C  Embarked_Q  Embarked_S
# 0           0       1 -0.592481           0           0           1
# 1           1       0  0.638789           1           0           0
# 2           1       0 -0.284663           0           0           1
# 3           1       0  0.407926           0           0           1
# 4           0       1  0.407926           0           0           1
# ..        ...     ...       ...         ...         ...         ...
# 886         0       1 -0.207709           0           0           1
# 887         1       0 -0.823344           0           0           1
# 888         0       0  0.000000           0           0           1
# 889         1       1 -0.284663           1           0           0
# 890         0       1  0.177063           0           1           0
#
# [891 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Survived', 'gender', 'Age', 'Embarked_C', 'Embarked_Q', 'Embarked_S'], dtype='str')

# %%
X=df[['gender', 'Age', 'Embarked_C', 'Embarked_Q', 'Embarked_S']]
y=df["Survived"]

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression 
model=LogisticRegression(max_iter=200)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
model.score(X_train,y_train)
# Out:
# 0.7879213483146067

# %%
pred=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.7821229050279329

# %%
import pickle 
pickle.dump(model,open("titanic.pkl","wb"))
print("successfully seved")
# Out:
# successfully seved
